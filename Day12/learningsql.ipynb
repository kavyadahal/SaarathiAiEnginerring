# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("school.db")

# %%
import pandas as pd

students_2 = {
    "roll_no": [1, 2, 3, 4, 5, 6, 7, 8],
    "student_name": [
        "Aarav Sharma",
        "Sita Rai",
        "Rohan Thapa",
        "Priya Gurung",
        "Nabin Karki",
        "Anisha Shrestha",
        "Suman KC",
        "Bikash Lama"
    ],
    "class": [10, 10, 9, 8, 10, 9, 8, 10],
    "city": [
        "Kathmandu",
        "Pokhara",
        "Lalitpur",
        "Bhaktapur",
        "Chitwan",
        "Biratnagar",
        "Butwal",
        "Dharan"
    ]
}
scores = {
    "roll_no": [1, 2, 3, 5, 6, 7, 9, 10],
    "math": [95, 81, 72, 65, 97, 70, 88, 79],
    "science": [90, 84, 76, 69, 95, 74, 92, 80]
}

scores_df = pd.DataFrame(scores)
students2_df = pd.DataFrame(students_2)

# %%
students2_df.to_sql("students_2", conn, if_exists="replace", index=False)
# Out:
# 8

# %%
# Out:
# 20
